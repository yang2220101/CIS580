# %% [markdown]
# Run the next code block. There will be two separate authentications needed. The first will download all extra files from the CIS580 shared drive files. The second connects your google drive to save files to 'cis580-2019-hw6'

# %%
# bootstrap environment into place
from google.colab import auth
auth.authenticate_user()

from googleapiclient.discovery import build
drive_service = build('drive', 'v3')

import io
import os
from googleapiclient.http import MediaIoBaseDownload

def download_file(fn, file_id):
    request = drive_service.files().get_media(fileId=file_id)
    downloaded = io.BytesIO()
    downloader = MediaIoBaseDownload(downloaded, request)
    done = False
    while done is False:
        # _ is a placeholder for a progress object that we ignore.
        # (Our file is small, so we skip reporting progress.)
        _, done = downloader.next_chunk()
    
    downloaded.seek(0)

    folder = fn.split('/')
    if len(folder) > 1:
        os.makedirs(folder[0], exist_ok=True)

    with open(fn, 'wb') as f:
        f.write(downloaded.read())

id_to_fn = {
        '1PIhom4rR_a_vm-zCt_1rYKbz8sd43Gel': "data/images.npz",
        '1IOxsTUF-MgmDRp3-0jPMJ-qo8yLZFCez': "data/train_data.npz",
        '1ZPRZoiuQVwWm88dWB4kWTBTtSQKBaDxs': "data/valid_data.npz",
        '1rJgn9NHdnwToyIERWbS8g_gZu19wAkkd': "data/kpt.npy",
        '1noGbThisv1HOi87dG66AfgQzpIv0o1y6': "data/misc_data.npz",
        '1Jp94eNQyXlTBYhqFFksbwRRl9VOGLAYT': "utils/__init__.py",
        '1UCCx78ZFL-BxsIScl0YkaLSRjw6Umliu': "utils/pose_utils.py",
        '1lV3oSGB2ygBj0vF2zaj_FKVaExz4-loi': "utils/plotting.py",
        '1td00aFXojVptGMz1XRTuVWSdpAHYi4lt': "utils/train_options.py",
        '18NNIqvS5-GB9xGWJX0wjHeC_RaaoKnWz': "hourglass.py",
        '1mJS9HFhDoUR1XGxRNQm2e-j4WZQn7Zhl': "dataset.py",
           }

# download all files into the vm
for fid, fn in id_to_fn.items():
    download_file(fn, fid)

# mount the user's google drive into the system
from google.colab import drive
drive.mount('/content/gdrive')
# create folder to write data to
os.makedirs('/content/gdrive/My Drive/cis580-2019-hw6', exist_ok=True)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# The next code block handles the external library imports.

# %%
from __future__ import division
from __future__ import print_function

import torch
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import make_grid

from hourglass import hg

from dataset import Dataset
from dataset import RandomFlipLR, RandomRescaleBB, RandomRotation,\
                    CropAndPad, LocsToHeatmaps,\
                    ToTensor, Normalize, Denormalize
from utils import TrainOptions, PoseUtils

from tqdm import tqdm
from PIL import Image
import os
from time import time
import numpy as np

# %% [markdown]
# Step 1) The Trainer class contains two locations where you must implement the training step and the test step as specified in the accompanying PDF

# %%
class Trainer(object):

    def __init__(self, options):
        self.options = options
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        train_transform_list = []
        train_transform_list.append(RandomRescaleBB(0.8, 1.2))
        train_transform_list.append(RandomFlipLR())
        train_transform_list.append(RandomRotation(degrees=options.degrees))
        train_transform_list.append(CropAndPad(out_size=(options.crop_size, options.crop_size)))
        train_transform_list.append(LocsToHeatmaps(out_size=(options.heatmap_size, options.heatmap_size)))
        train_transform_list.append(ToTensor())
        train_transform_list.append(Normalize())
        test_transform_list = [CropAndPad(out_size=(options.crop_size, options.crop_size))]
        test_transform_list.append(LocsToHeatmaps(out_size=(options.heatmap_size, options.heatmap_size)))
        test_transform_list.append(ToTensor())
        test_transform_list.append(Normalize())
        self.train_ds = Dataset(is_train=True, transform=transforms.Compose(train_transform_list))
        self.test_ds = Dataset(is_train=False, transform=transforms.Compose(test_transform_list))

        self.model = hg(num_stacks=options.num_stacks, num_blocks=options.num_blocks, num_classes=options.num_classes).to(self.device)
        # define loss function and optimizer
        self.heatmap_loss = torch.nn.MSELoss().to(self.device) # for Global loss
        self.optimizer = torch.optim.RMSprop(self.model.parameters(),
                                             lr = options.lr)


        self.pose_utils = PoseUtils(detection_thresh=options.detection_thresh, dist_thresh=options.dist_thresh)

        self.train_data_loader = DataLoader(self.train_ds, batch_size=options.batch_size,
                                            num_workers=options.num_workers,
                                            pin_memory=True,
                                            shuffle=True)
        self.test_data_loader = DataLoader(self.test_ds, batch_size=options.test_batch_size,
                                           num_workers=options.num_workers,
                                           pin_memory=True,
                                           shuffle=True)

        self.summary_iters = []
        self.losses = []
        self.pcks = []

    def train(self):
        self.total_step_count = 0
        start_time = time()
        for epoch in range(1,self.options.num_epochs+1):
            elapsed_time = time() - start_time
            seconds_per_epoch = elapsed_time / epoch
            remaining_time = (self.options.num_epochs - epoch) * seconds_per_epoch

            print("Epoch %d/%d - Elapsed Time %f - Remaining Time %f" %
                    (epoch, self.options.num_epochs,
                        elapsed_time, remaining_time))

            for step, batch in enumerate(self.train_data_loader):
                self.model.train()
                batch = {k: v.to(self.device) if isinstance(v, torch.Tensor) else v for k,v in batch.items()}
                """
                ADD YOUR CODE FOR THE TRAINING STEP HERE
                You have to name the output of your neural network pred_heatmap_list
                This list contains the output heatmaps for each stack of the Stacked Hourglass model
                Since we are using only 1 stack in this homework, pred_heatmap_list will contain only 1 tensor
                """
                inputs = batch['image']
                labels = batch['keypoint_heatmaps']
                self.optimizer.zero_grad()
                pred_heatmap_list = self.model(inputs)
                loss = self.heatmap_loss(pred_heatmap_list[0], labels)
                loss.backward()
                self.optimizer.step()
                
               #end of code
                self.total_step_count += 1
                if self.total_step_count % self.options.summary_steps == 0:
                    self.save_summaries(batch, pred_heatmap_list[-1].detach(), loss.detach(), mode='train')
                if self.total_step_count % self.options.test_steps == 0:
                    self.model.eval()
                    batch = next(iter(self.test_data_loader))
                    batch = {k: v.to(self.device) if isinstance(v, torch.Tensor) else v for k,v in batch.items()}
                    """
                    ADD YOUR CODE FOR THE TEST STEP HERE
                    What you have to do is to perform a forward pass and record the loss and the output
                    """
                    with torch.no_grad():
                      pred_heatmap_list = self.model(batch['image'])
                      loss = self.heatmap_loss(pred_heatmap_list[0], batch['keypoint_heatmaps'])
                    
                    
                    
                    self.save_summaries(batch, pred_heatmap_list[-1], loss, mode='test')

        checkpoint = {'model': self.model.state_dict()}
        torch.save(checkpoint, '/content/gdrive/My Drive/cis580-2019-hw6/model_checkpoint.pt')

    def save_summaries(self, batch, pred_heatmaps, loss, mode='train'):
        gt_heatmaps = batch['keypoint_heatmaps'].to(self.device)
        pck = self.pose_utils.pck(gt_heatmaps, pred_heatmaps)

        batch = Denormalize()(batch)
        images = batch['image']

        gt_image_keypoints, pred_image_keypoints = self.pose_utils.draw_keypoints_with_labels(images, gt_heatmaps, pred_heatmaps)

        gt_image_keypoints_grid = make_grid(gt_image_keypoints, pad_value=1, nrow=3)
        pred_image_keypoints_grid = make_grid(pred_image_keypoints, pad_value=1, nrow=3)

        pred_heatmaps_grid = make_grid(pred_heatmaps[0,:,:,:].unsqueeze(0).transpose(0,1), pad_value=1, nrow=5)
        pred_heatmaps_grid[pred_heatmaps_grid > 1] = 1
        pred_heatmaps_grid[pred_heatmaps_grid < 0] = 0

        self.losses.append(loss)
        self.pcks.append(pck)
        self.summary_iters.append(self.total_step_count)

        folder = '/content/gdrive/My Drive/cis580-2019-hw6/logs/%d' % self.total_step_count
        os.makedirs(folder, exist_ok=True)

        gt_ikg = Image.fromarray((gt_image_keypoints_grid.cpu().detach().numpy().transpose(1,2,0) * 255.).astype(np.uint8))
        pred_ikg = Image.fromarray((pred_image_keypoints_grid.cpu().detach().numpy().transpose(1,2,0) * 255.).astype(np.uint8))
        pred_hg = Image.fromarray((pred_heatmaps_grid.cpu().detach().numpy().transpose(1,2,0) * 255.).astype(np.uint8))

        gt_ikg.save(os.path.join(folder, mode + '_gt_image_keypoints.jpg'))
        pred_ikg.save(os.path.join(folder, mode + '_pred_image_keypoints.jpg'))
        pred_hg.save(os.path.join(folder, mode + '_pred_heatmaps.jpg'))

# %% [markdown]
# The next block will start the training process. Be sure to run the above block first every time you want to test changes to the code.

# %%
options = TrainOptions().parse_args(["--name=gascan",
                                     "--summary_steps=200",
                                     "--num_epochs=400",
                                     "--test_steps=1000"])
trainer = Trainer(options)
trainer.train()
# Out:
# Epoch 1/400 - Elapsed Time 0.000003 - Remaining Time 0.001332
# Epoch 2/400 - Elapsed Time 4.836459 - Remaining Time 962.455325
# Epoch 3/400 - Elapsed Time 9.497118 - Remaining Time 1256.785281
# Epoch 4/400 - Elapsed Time 14.257964 - Remaining Time 1411.538449
# Epoch 5/400 - Elapsed Time 18.952822 - Remaining Time 1497.272936
# Epoch 6/400 - Elapsed Time 23.657903 - Remaining Time 1553.535627
# Epoch 7/400 - Elapsed Time 28.431904 - Remaining Time 1596.248329
# Epoch 8/400 - Elapsed Time 33.268664 - Remaining Time 1630.164530
# Epoch 9/400 - Elapsed Time 37.990137 - Remaining Time 1650.460380
# Epoch 10/400 - Elapsed Time 42.682745 - Remaining Time 1664.627045
# Epoch 11/400 - Elapsed Time 47.573467 - Remaining Time 1682.370771
# Epoch 12/400 - Elapsed Time 55.447225 - Remaining Time 1792.793619
# Epoch 13/400 - Elapsed Time 60.337829 - Remaining Time 1796.210752
# Epoch 14/400 - Elapsed Time 65.231935 - Remaining Time 1798.537631
# Epoch 15/400 - Elapsed Time 69.934600 - Remaining Time 1794.988063
# Epoch 16/400 - Elapsed Time 74.757840 - Remaining Time 1794.188158
# Epoch 17/400 - Elapsed Time 79.661885 - Remaining Time 1794.735410
# Epoch 18/400 - Elapsed Time 84.495463 - Remaining Time 1793.181500
# Epoch 19/400 - Elapsed Time 89.329131 - Remaining Time 1791.284156
# Epoch 20/400 - Elapsed Time 94.126057 - Remaining Time 1788.395081
# Epoch 21/400 - Elapsed Time 98.976664 - Remaining Time 1786.293123
# Epoch 22/400 - Elapsed Time 103.792968 - Remaining Time 1783.351905
# Epoch 23/400 - Elapsed Time 111.266823 - Remaining Time 1823.808364
# Epoch 24/400 - Elapsed Time 116.112518 - Remaining Time 1819.096120
# Epoch 25/400 - Elapsed Time 121.041018 - Remaining Time 1815.615267
# Epoch 26/400 - Elapsed Time 125.940988 - Remaining Time 1811.612671
# Epoch 27/400 - Elapsed Time 131.142238 - Remaining Time 1811.705731
# Epoch 28/400 - Elapsed Time 136.387009 - Remaining Time 1811.998829
# Epoch 29/400 - Elapsed Time 141.209511 - Remaining Time 1806.507883
# Epoch 30/400 - Elapsed Time 146.134204 - Remaining Time 1802.321851
# Epoch 31/400 - Elapsed Time 150.986858 - Remaining Time 1797.230669
# Epoch 32/400 - Elapsed Time 155.868753 - Remaining Time 1792.490664
# Epoch 33/400 - Elapsed Time 163.170971 - Remaining Time 1814.658977
# Epoch 34/400 - Elapsed Time 168.038911 - Remaining Time 1808.889457
# Epoch 35/400 - Elapsed Time 172.936690 - Remaining Time 1803.482623
# Epoch 36/400 - Elapsed Time 177.943967 - Remaining Time 1799.211218
# Epoch 37/400 - Elapsed Time 182.898205 - Remaining Time 1794.379685
# Epoch 38/400 - Elapsed Time 187.760438 - Remaining Time 1788.665227
# Epoch 39/400 - Elapsed Time 192.749418 - Remaining Time 1784.167694
# Epoch 40/400 - Elapsed Time 198.003726 - Remaining Time 1782.033536
# Epoch 41/400 - Elapsed Time 203.314591 - Remaining Time 1780.242394
# Epoch 42/400 - Elapsed Time 208.381168 - Remaining Time 1776.201385
# Epoch 43/400 - Elapsed Time 213.661639 - Remaining Time 1773.888491
# Epoch 44/400 - Elapsed Time 221.504602 - Remaining Time 1792.173600
# Epoch 45/400 - Elapsed Time 226.490194 - Remaining Time 1786.755974
# Epoch 46/400 - Elapsed Time 231.473709 - Remaining Time 1781.341153
# Epoch 47/400 - Elapsed Time 236.284198 - Remaining Time 1774.645147
# Epoch 48/400 - Elapsed Time 241.093486 - Remaining Time 1768.018898
# Epoch 49/400 - Elapsed Time 245.957880 - Remaining Time 1761.861545
# Epoch 50/400 - Elapsed Time 250.838075 - Remaining Time 1755.866526
# Epoch 51/400 - Elapsed Time 255.709798 - Remaining Time 1749.857247
# Epoch 52/400 - Elapsed Time 260.675610 - Remaining Time 1744.521392
# Epoch 53/400 - Elapsed Time 265.598444 - Remaining Time 1738.918116
# Epoch 54/400 - Elapsed Time 276.968354 - Remaining Time 1774.649084
# Epoch 55/400 - Elapsed Time 281.907762 - Remaining Time 1768.330509
# Epoch 56/400 - Elapsed Time 286.909047 - Remaining Time 1762.441288
# Epoch 57/400 - Elapsed Time 292.215624 - Remaining Time 1758.420332
# Epoch 58/400 - Elapsed Time 297.472003 - Remaining Time 1754.059055
# Epoch 59/400 - Elapsed Time 302.498675 - Remaining Time 1748.339799
# Epoch 60/400 - Elapsed Time 307.408204 - Remaining Time 1741.979823
# Epoch 61/400 - Elapsed Time 312.322654 - Remaining Time 1735.694747
# Epoch 62/400 - Elapsed Time 317.365554 - Remaining Time 1730.154150
# Epoch 63/400 - Elapsed Time 322.315998 - Remaining Time 1724.134785
# Epoch 64/400 - Elapsed Time 327.241682 - Remaining Time 1718.018828
# Epoch 65/400 - Elapsed Time 334.947401 - Remaining Time 1726.267375
# Epoch 66/400 - Elapsed Time 339.927510 - Remaining Time 1720.239216
# Epoch 67/400 - Elapsed Time 344.908054 - Remaining Time 1714.244507
# Epoch 68/400 - Elapsed Time 349.891023 - Remaining Time 1708.291465
# Epoch 69/400 - Elapsed Time 354.781341 - Remaining Time 1701.922087
# Epoch 70/400 - Elapsed Time 359.682355 - Remaining Time 1695.645386
# Epoch 71/400 - Elapsed Time 364.671705 - Remaining Time 1689.816772
# Epoch 72/400 - Elapsed Time 369.708983 - Remaining Time 1684.229811
# Epoch 73/400 - Elapsed Time 375.057458 - Remaining Time 1680.051903
# Epoch 74/400 - Elapsed Time 380.165639 - Remaining Time 1674.783763
# Epoch 75/400 - Elapsed Time 387.438879 - Remaining Time 1678.901810
# Epoch 76/400 - Elapsed Time 392.323210 - Remaining Time 1672.535791
# Epoch 77/400 - Elapsed Time 397.236898 - Remaining Time 1666.331404
# Epoch 78/400 - Elapsed Time 402.168835 - Remaining Time 1660.235446
# Epoch 79/400 - Elapsed Time 407.151882 - Remaining Time 1654.376636
# Epoch 80/400 - Elapsed Time 412.138306 - Remaining Time 1648.553226
# Epoch 81/400 - Elapsed Time 416.991390 - Remaining Time 1642.225352
# Epoch 82/400 - Elapsed Time 421.880190 - Remaining Time 1636.071955
# Epoch 83/400 - Elapsed Time 426.768351 - Remaining Time 1629.946593
# Epoch 84/400 - Elapsed Time 431.644351 - Remaining Time 1623.804939
# Epoch 85/400 - Elapsed Time 436.590968 - Remaining Time 1617.954763
# Epoch 86/400 - Elapsed Time 444.034916 - Remaining Time 1621.243763
# Epoch 87/400 - Elapsed Time 448.995252 - Remaining Time 1615.350733
# Epoch 88/400 - Elapsed Time 454.388127 - Remaining Time 1611.012451
# Epoch 89/400 - Elapsed Time 459.640211 - Remaining Time 1606.158489
# Epoch 90/400 - Elapsed Time 464.529804 - Remaining Time 1600.047101
# Epoch 91/400 - Elapsed Time 469.470441 - Remaining Time 1594.135893
# Epoch 92/400 - Elapsed Time 474.497850 - Remaining Time 1588.536282
# Epoch 93/400 - Elapsed Time 479.664095 - Remaining Time 1583.407283
# Epoch 94/400 - Elapsed Time 484.857550 - Remaining Time 1578.366066
# Epoch 95/400 - Elapsed Time 490.077833 - Remaining Time 1573.407780
# Epoch 96/400 - Elapsed Time 497.707053 - Remaining Time 1576.072335
# Epoch 97/400 - Elapsed Time 502.916580 - Remaining Time 1570.966225
# Epoch 98/400 - Elapsed Time 508.332745 - Remaining Time 1566.494785
# Epoch 99/400 - Elapsed Time 513.798435 - Remaining Time 1562.154837
# Epoch 100/400 - Elapsed Time 519.070487 - Remaining Time 1557.211460
# Epoch 101/400 - Elapsed Time 524.336911 - Remaining Time 1552.244914
# Epoch 102/400 - Elapsed Time 529.785878 - Remaining Time 1547.805801
# Epoch 103/400 - Elapsed Time 535.098575 - Remaining Time 1542.954144
# Epoch 104/400 - Elapsed Time 540.357760 - Remaining Time 1537.941317
# Epoch 105/400 - Elapsed Time 545.230888 - Remaining Time 1531.839161
# Epoch 106/400 - Elapsed Time 550.221882 - Remaining Time 1526.087107
# Epoch 107/400 - Elapsed Time 561.979776 - Remaining Time 1538.879199
# Epoch 108/400 - Elapsed Time 566.926486 - Remaining Time 1532.801239
# Epoch 109/400 - Elapsed Time 571.812479 - Remaining Time 1526.581939
# Epoch 110/400 - Elapsed Time 576.657097 - Remaining Time 1520.277800
# Epoch 111/400 - Elapsed Time 581.484909 - Remaining Time 1513.956205
# Epoch 112/400 - Elapsed Time 586.402283 - Remaining Time 1507.891584
# Epoch 113/400 - Elapsed Time 591.283325 - Remaining Time 1501.754993
# Epoch 114/400 - Elapsed Time 596.249469 - Remaining Time 1495.853931
# Epoch 115/400 - Elapsed Time 601.140953 - Remaining Time 1489.784101
# Epoch 116/400 - Elapsed Time 606.088498 - Remaining Time 1483.871840
# Epoch 117/400 - Elapsed Time 613.495199 - Remaining Time 1483.924285
# Epoch 118/400 - Elapsed Time 618.869163 - Remaining Time 1478.992405
# Epoch 119/400 - Elapsed Time 623.777676 - Remaining Time 1472.954007
# Epoch 120/400 - Elapsed Time 628.703749 - Remaining Time 1466.975414
# Epoch 121/400 - Elapsed Time 633.697191 - Remaining Time 1461.169555
# Epoch 122/400 - Elapsed Time 638.632832 - Remaining Time 1455.245306
# Epoch 123/400 - Elapsed Time 643.584603 - Remaining Time 1449.373455
# Epoch 124/400 - Elapsed Time 648.607163 - Remaining Time 1443.674008
# Epoch 125/400 - Elapsed Time 653.622862 - Remaining Time 1437.970296
# Epoch 126/400 - Elapsed Time 658.564496 - Remaining Time 1432.116443
# Epoch 127/400 - Elapsed Time 663.504363 - Remaining Time 1426.273157
# Epoch 128/400 - Elapsed Time 668.625991 - Remaining Time 1420.830231
# Epoch 129/400 - Elapsed Time 673.559651 - Remaining Time 1414.997406
# Epoch 130/400 - Elapsed Time 678.454617 - Remaining Time 1409.098051
# Epoch 131/400 - Elapsed Time 683.381832 - Remaining Time 1403.280250
# Epoch 132/400 - Elapsed Time 688.333341 - Remaining Time 1397.525268
# Epoch 133/400 - Elapsed Time 693.579906 - Remaining Time 1392.374699
# Epoch 134/400 - Elapsed Time 698.917834 - Remaining Time 1387.404058
# Epoch 135/400 - Elapsed Time 703.790586 - Remaining Time 1381.514854
# Epoch 136/400 - Elapsed Time 708.732763 - Remaining Time 1375.775364
# Epoch 137/400 - Elapsed Time 713.635633 - Remaining Time 1369.972055
# Epoch 138/400 - Elapsed Time 718.756697 - Remaining Time 1364.596049
# Epoch 139/400 - Elapsed Time 723.695748 - Remaining Time 1358.881945
# Epoch 140/400 - Elapsed Time 728.754823 - Remaining Time 1353.401814
# Epoch 141/400 - Elapsed Time 733.597367 - Remaining Time 1347.529916
# Epoch 142/400 - Elapsed Time 738.484474 - Remaining Time 1341.753481
# Epoch 143/400 - Elapsed Time 743.382573 - Remaining Time 1336.009239
# Epoch 144/400 - Elapsed Time 748.361568 - Remaining Time 1330.420566
# Epoch 145/400 - Elapsed Time 753.301967 - Remaining Time 1324.772424
# Epoch 146/400 - Elapsed Time 758.232624 - Remaining Time 1319.117031
# Epoch 147/400 - Elapsed Time 763.154987 - Remaining Time 1313.457223
# Epoch 148/400 - Elapsed Time 768.071139 - Remaining Time 1307.796804
# Epoch 149/400 - Elapsed Time 773.483798 - Remaining Time 1302.982773
# Epoch 150/400 - Elapsed Time 778.788967 - Remaining Time 1297.981611
# Epoch 151/400 - Elapsed Time 783.864679 - Remaining Time 1292.598047
# Epoch 152/400 - Elapsed Time 788.750278 - Remaining Time 1286.908348
# Epoch 153/400 - Elapsed Time 793.651506 - Remaining Time 1281.254392
# Epoch 154/400 - Elapsed Time 798.596054 - Remaining Time 1275.679411
# Epoch 155/400 - Elapsed Time 803.530165 - Remaining Time 1270.096068
# Epoch 156/400 - Elapsed Time 808.348628 - Remaining Time 1264.340162
# Epoch 157/400 - Elapsed Time 813.395460 - Remaining Time 1258.949660
# Epoch 158/400 - Elapsed Time 818.820467 - Remaining Time 1254.142740
# Epoch 159/400 - Elapsed Time 826.245347 - Remaining Time 1252.359299
# Epoch 160/400 - Elapsed Time 831.376446 - Remaining Time 1247.064669
# Epoch 161/400 - Elapsed Time 836.628661 - Remaining Time 1241.951863
# Epoch 162/400 - Elapsed Time 841.538645 - Remaining Time 1236.334553
# Epoch 163/400 - Elapsed Time 846.392616 - Remaining Time 1230.644478
# Epoch 164/400 - Elapsed Time 851.333202 - Remaining Time 1225.089242
# Epoch 165/400 - Elapsed Time 856.527509 - Remaining Time 1219.902816
# Epoch 166/400 - Elapsed Time 861.845245 - Remaining Time 1214.890285
# Epoch 167/400 - Elapsed Time 866.855056 - Remaining Time 1209.444480
# Epoch 168/400 - Elapsed Time 871.784156 - Remaining Time 1203.892406
# Epoch 169/400 - Elapsed Time 876.663893 - Remaining Time 1198.280233
# Epoch 170/400 - Elapsed Time 881.882825 - Remaining Time 1193.135587
# Epoch 171/400 - Elapsed Time 886.906615 - Remaining Time 1187.728742
# Epoch 172/400 - Elapsed Time 891.898006 - Remaining Time 1182.283404
# Epoch 173/400 - Elapsed Time 896.871343 - Remaining Time 1176.819623
# Epoch 174/400 - Elapsed Time 901.770612 - Remaining Time 1171.265278
# Epoch 175/400 - Elapsed Time 906.725773 - Remaining Time 1165.790279
# Epoch 176/400 - Elapsed Time 911.779889 - Remaining Time 1160.447132
# Epoch 177/400 - Elapsed Time 916.720021 - Remaining Time 1154.963643
# Epoch 178/400 - Elapsed Time 921.741640 - Remaining Time 1149.587888
# Epoch 179/400 - Elapsed Time 926.722771 - Remaining Time 1144.166103
# Epoch 180/400 - Elapsed Time 931.848124 - Remaining Time 1138.925484
# Epoch 181/400 - Elapsed Time 937.236769 - Remaining Time 1134.004709
# Epoch 182/400 - Elapsed Time 942.505737 - Remaining Time 1128.935444
# Epoch 183/400 - Elapsed Time 947.421978 - Remaining Time 1123.445733
# Epoch 184/400 - Elapsed Time 952.410454 - Remaining Time 1118.047055
# Epoch 185/400 - Elapsed Time 957.359186 - Remaining Time 1112.606621
# Epoch 186/400 - Elapsed Time 962.310529 - Remaining Time 1107.174479
# Epoch 187/400 - Elapsed Time 967.217658 - Remaining Time 1101.697119
# Epoch 188/400 - Elapsed Time 972.192939 - Remaining Time 1096.302676
# Epoch 189/400 - Elapsed Time 977.149976 - Remaining Time 1090.892301
# Epoch 190/400 - Elapsed Time 982.096715 - Remaining Time 1085.475317
# Epoch 191/400 - Elapsed Time 987.458556 - Remaining Time 1080.517477
# Epoch 192/400 - Elapsed Time 992.349313 - Remaining Time 1075.045090
# Epoch 193/400 - Elapsed Time 997.273056 - Remaining Time 1069.614107
# Epoch 194/400 - Elapsed Time 1002.263231 - Remaining Time 1064.258895
# Epoch 195/400 - Elapsed Time 1007.210107 - Remaining Time 1058.861908
# Epoch 196/400 - Elapsed Time 1012.228074 - Remaining Time 1053.543505
# Epoch 197/400 - Elapsed Time 1017.587061 - Remaining Time 1048.579560
# Epoch 198/400 - Elapsed Time 1022.942242 - Remaining Time 1043.607742
# Epoch 199/400 - Elapsed Time 1027.856147 - Remaining Time 1038.186360
# Epoch 200/400 - Elapsed Time 1032.800229 - Remaining Time 1032.800229
# Epoch 201/400 - Elapsed Time 1037.822681 - Remaining Time 1027.496088
# Epoch 202/400 - Elapsed Time 1042.703475 - Remaining Time 1022.055881
# Epoch 203/400 - Elapsed Time 1047.670096 - Remaining Time 1016.704477
# Epoch 204/400 - Elapsed Time 1052.533380 - Remaining Time 1011.257561
# Epoch 205/400 - Elapsed Time 1057.388638 - Remaining Time 1005.808705
# Epoch 206/400 - Elapsed Time 1062.425693 - Remaining Time 1000.536818
# Epoch 207/400 - Elapsed Time 1067.419841 - Remaining Time 995.227195
# Epoch 208/400 - Elapsed Time 1072.318850 - Remaining Time 989.832785
# Epoch 209/400 - Elapsed Time 1077.188550 - Remaining Time 984.416330
# Epoch 210/400 - Elapsed Time 1082.069718 - Remaining Time 979.015459
# Epoch 211/400 - Elapsed Time 1086.903640 - Remaining Time 973.577194
# Epoch 212/400 - Elapsed Time 1093.932093 - Remaining Time 970.090724
# Epoch 213/400 - Elapsed Time 1099.208509 - Remaining Time 965.032822
# Epoch 214/400 - Elapsed Time 1104.420146 - Remaining Time 959.916576
# Epoch 215/400 - Elapsed Time 1109.394860 - Remaining Time 954.595577
# Epoch 216/400 - Elapsed Time 1114.311118 - Remaining Time 949.227990
# Epoch 217/400 - Elapsed Time 1119.168957 - Remaining Time 943.815296
# Epoch 218/400 - Elapsed Time 1124.094224 - Remaining Time 938.463985
# Epoch 219/400 - Elapsed Time 1129.557690 - Remaining Time 933.561378
# Epoch 220/400 - Elapsed Time 1135.012481 - Remaining Time 928.646576
# Epoch 221/400 - Elapsed Time 1140.451846 - Remaining Time 923.714391
# Epoch 222/400 - Elapsed Time 1145.276543 - Remaining Time 918.284796
# Epoch 223/400 - Elapsed Time 1150.708877 - Remaining Time 913.342920
# Epoch 224/400 - Elapsed Time 1155.477185 - Remaining Time 907.874931
# Epoch 225/400 - Elapsed Time 1160.306295 - Remaining Time 902.460452
# Epoch 226/400 - Elapsed Time 1165.388421 - Remaining Time 897.245952
# Epoch 227/400 - Elapsed Time 1170.319607 - Remaining Time 891.917586
# Epoch 228/400 - Elapsed Time 1175.486990 - Remaining Time 886.770888
# Epoch 229/400 - Elapsed Time 1180.886079 - Remaining Time 881.797028
# Epoch 230/400 - Elapsed Time 1185.863498 - Remaining Time 876.507803
# Epoch 231/400 - Elapsed Time 1190.886136 - Remaining Time 871.254359
# Epoch 232/400 - Elapsed Time 1195.988051 - Remaining Time 866.060313
# Epoch 233/400 - Elapsed Time 1201.116071 - Remaining Time 860.885767
# Epoch 234/400 - Elapsed Time 1205.941979 - Remaining Time 855.497301
# Epoch 235/400 - Elapsed Time 1210.796213 - Remaining Time 850.133511
# Epoch 236/400 - Elapsed Time 1215.687336 - Remaining Time 844.799674
# Epoch 237/400 - Elapsed Time 1220.572103 - Remaining Time 839.465202
# Epoch 238/400 - Elapsed Time 1225.632432 - Remaining Time 834.254008
# Epoch 239/400 - Elapsed Time 1230.497008 - Remaining Time 828.912210
# Epoch 240/400 - Elapsed Time 1235.371904 - Remaining Time 823.581269
# Epoch 241/400 - Elapsed Time 1240.225513 - Remaining Time 818.240069
# Epoch 242/400 - Elapsed Time 1245.158537 - Remaining Time 812.954748
# Epoch 243/400 - Elapsed Time 1249.985524 - Remaining Time 807.603816
# Epoch 244/400 - Elapsed Time 1255.548155 - Remaining Time 802.727509
# Epoch 245/400 - Elapsed Time 1260.896596 - Remaining Time 797.710091
# Epoch 246/400 - Elapsed Time 1266.079956 - Remaining Time 792.586639
# Epoch 247/400 - Elapsed Time 1271.000349 - Remaining Time 787.299811
# Epoch 248/400 - Elapsed Time 1276.581057 - Remaining Time 782.420648
# Epoch 249/400 - Elapsed Time 1282.131491 - Remaining Time 777.517490
# Epoch 250/400 - Elapsed Time 1287.949792 - Remaining Time 772.769875
# Epoch 251/400 - Elapsed Time 1292.877591 - Remaining Time 767.485104
# Epoch 252/400 - Elapsed Time 1297.756567 - Remaining Time 762.174492
# Epoch 253/400 - Elapsed Time 1302.726281 - Remaining Time 756.920013
# Epoch 254/400 - Elapsed Time 1307.876788 - Remaining Time 751.771697
# Epoch 255/400 - Elapsed Time 1312.763633 - Remaining Time 746.473439
# Epoch 256/400 - Elapsed Time 1317.725089 - Remaining Time 741.220362
# Epoch 257/400 - Elapsed Time 1322.644659 - Remaining Time 735.946250
# Epoch 258/400 - Elapsed Time 1327.541503 - Remaining Time 730.662378
# Epoch 259/400 - Elapsed Time 1332.415104 - Remaining Time 725.368841
# Epoch 260/400 - Elapsed Time 1337.686434 - Remaining Time 720.292695
# Epoch 261/400 - Elapsed Time 1343.002827 - Remaining Time 715.239054
# Epoch 262/400 - Elapsed Time 1347.968896 - Remaining Time 709.998884
# Epoch 263/400 - Elapsed Time 1352.945745 - Remaining Time 704.766415
# Epoch 264/400 - Elapsed Time 1357.882505 - Remaining Time 699.515230
# Epoch 265/400 - Elapsed Time 1365.040831 - Remaining Time 695.398159
# Epoch 266/400 - Elapsed Time 1369.935269 - Remaining Time 690.117767
# Epoch 267/400 - Elapsed Time 1374.877683 - Remaining Time 684.864164
# Epoch 268/400 - Elapsed Time 1379.784467 - Remaining Time 679.595334
# Epoch 269/400 - Elapsed Time 1384.722016 - Remaining Time 674.344179
# Epoch 270/400 - Elapsed Time 1389.545046 - Remaining Time 669.040207
# Epoch 271/400 - Elapsed Time 1394.433170 - Remaining Time 663.770771
# Epoch 272/400 - Elapsed Time 1399.399163 - Remaining Time 658.540783
# Epoch 273/400 - Elapsed Time 1404.379874 - Remaining Time 653.319575
# Epoch 274/400 - Elapsed Time 1409.310493 - Remaining Time 648.077088
# Epoch 275/400 - Elapsed Time 1414.481148 - Remaining Time 642.945976
# Epoch 276/400 - Elapsed Time 1419.822221 - Remaining Time 637.891143
# Epoch 277/400 - Elapsed Time 1425.142879 - Remaining Time 632.825178
# Epoch 278/400 - Elapsed Time 1430.092097 - Remaining Time 627.594374
# Epoch 279/400 - Elapsed Time 1435.163937 - Remaining Time 622.418768
# Epoch 280/400 - Elapsed Time 1440.608538 - Remaining Time 617.403659
# Epoch 281/400 - Elapsed Time 1445.955816 - Remaining Time 612.344278
# Epoch 282/400 - Elapsed Time 1450.953458 - Remaining Time 607.136553
# Epoch 283/400 - Elapsed Time 1455.965916 - Remaining Time 601.936439
# Epoch 284/400 - Elapsed Time 1461.058209 - Remaining Time 596.770254
# Epoch 285/400 - Elapsed Time 1465.927780 - Remaining Time 591.514718
# Epoch 286/400 - Elapsed Time 1471.278385 - Remaining Time 586.453622
# Epoch 287/400 - Elapsed Time 1476.250104 - Remaining Time 581.241330
# Epoch 288/400 - Elapsed Time 1481.239010 - Remaining Time 576.037393
# Epoch 289/400 - Elapsed Time 1486.194494 - Remaining Time 570.822107
# Epoch 290/400 - Elapsed Time 1491.013582 - Remaining Time 565.556876
# Epoch 291/400 - Elapsed Time 1496.011141 - Remaining Time 560.361562
# Epoch 292/400 - Elapsed Time 1501.321857 - Remaining Time 555.283427
# Epoch 293/400 - Elapsed Time 1506.581246 - Remaining Time 550.184960
# Epoch 294/400 - Elapsed Time 1511.559506 - Remaining Time 544.984040
# Epoch 295/400 - Elapsed Time 1516.555075 - Remaining Time 539.790789
# Epoch 296/400 - Elapsed Time 1521.656888 - Remaining Time 534.636204
# Epoch 297/400 - Elapsed Time 1526.577545 - Remaining Time 529.419149
# Epoch 298/400 - Elapsed Time 1531.516719 - Remaining Time 524.210421
# Epoch 299/400 - Elapsed Time 1536.344155 - Remaining Time 518.965751
# Epoch 300/400 - Elapsed Time 1541.281210 - Remaining Time 513.760403
# Epoch 301/400 - Elapsed Time 1546.399444 - Remaining Time 508.616428
# Epoch 302/400 - Elapsed Time 1551.367635 - Remaining Time 503.423934
# Epoch 303/400 - Elapsed Time 1556.185895 - Remaining Time 498.184924
# Epoch 304/400 - Elapsed Time 1561.152553 - Remaining Time 492.995543
# Epoch 305/400 - Elapsed Time 1565.988097 - Remaining Time 487.766784
# Epoch 306/400 - Elapsed Time 1570.858368 - Remaining Time 482.551263
# Epoch 307/400 - Elapsed Time 1576.136807 - Remaining Time 477.461639
# Epoch 308/400 - Elapsed Time 1581.546908 - Remaining Time 472.410115
# Epoch 309/400 - Elapsed Time 1586.739081 - Remaining Time 467.292092
# Epoch 310/400 - Elapsed Time 1591.582847 - Remaining Time 462.072440
# Epoch 311/400 - Elapsed Time 1596.491980 - Remaining Time 456.873911
# Epoch 312/400 - Elapsed Time 1601.447458 - Remaining Time 451.690309
# Epoch 313/400 - Elapsed Time 1606.344831 - Remaining Time 446.492014
# Epoch 314/400 - Elapsed Time 1611.276754 - Remaining Time 441.305098
# Epoch 315/400 - Elapsed Time 1616.241462 - Remaining Time 436.128648
# Epoch 316/400 - Elapsed Time 1621.140099 - Remaining Time 430.935976
# Epoch 317/400 - Elapsed Time 1628.102217 - Remaining Time 426.285439
# Epoch 318/400 - Elapsed Time 1632.903063 - Remaining Time 421.063054
# Epoch 319/400 - Elapsed Time 1637.809901 - Remaining Time 415.870226
# Epoch 320/400 - Elapsed Time 1642.748732 - Remaining Time 410.687183
# Epoch 321/400 - Elapsed Time 1647.775220 - Remaining Time 405.527235
# Epoch 322/400 - Elapsed Time 1652.651505 - Remaining Time 400.331731
# Epoch 323/400 - Elapsed Time 1657.670423 - Remaining Time 395.172206
# Epoch 324/400 - Elapsed Time 1663.025870 - Remaining Time 390.092488
# Epoch 325/400 - Elapsed Time 1668.264769 - Remaining Time 384.984177
# Epoch 326/400 - Elapsed Time 1673.324793 - Remaining Time 379.834462
# Epoch 327/400 - Elapsed Time 1678.271822 - Remaining Time 374.660070
# Epoch 328/400 - Elapsed Time 1683.464582 - Remaining Time 369.541006
# Epoch 329/400 - Elapsed Time 1688.314872 - Remaining Time 364.347586
# Epoch 330/400 - Elapsed Time 1693.326868 - Remaining Time 359.190548
# Epoch 331/400 - Elapsed Time 1698.261188 - Remaining Time 354.018193
# Epoch 332/400 - Elapsed Time 1703.092570 - Remaining Time 348.826189
# Epoch 333/400 - Elapsed Time 1708.094253 - Remaining Time 343.670615
# Epoch 334/400 - Elapsed Time 1713.017975 - Remaining Time 338.500558
# Epoch 335/400 - Elapsed Time 1717.921548 - Remaining Time 333.328061
# Epoch 336/400 - Elapsed Time 1722.763032 - Remaining Time 328.145340
# Epoch 337/400 - Elapsed Time 1727.672680 - Remaining Time 322.977385
# Epoch 338/400 - Elapsed Time 1732.736614 - Remaining Time 317.839261
# Epoch 339/400 - Elapsed Time 1737.826195 - Remaining Time 312.706188
# Epoch 340/400 - Elapsed Time 1743.203481 - Remaining Time 307.624144
# Epoch 341/400 - Elapsed Time 1748.568722 - Remaining Time 302.538283
# Epoch 342/400 - Elapsed Time 1753.978744 - Remaining Time 297.458383
# Epoch 343/400 - Elapsed Time 1758.998721 - Remaining Time 292.311741
# Epoch 344/400 - Elapsed Time 1763.897134 - Remaining Time 287.146045
# Epoch 345/400 - Elapsed Time 1768.832142 - Remaining Time 281.987733
# Epoch 346/400 - Elapsed Time 1773.653548 - Remaining Time 276.812981
# Epoch 347/400 - Elapsed Time 1778.723742 - Remaining Time 271.678266
# Epoch 348/400 - Elapsed Time 1783.656578 - Remaining Time 266.523397
# Epoch 349/400 - Elapsed Time 1788.851781 - Remaining Time 261.408140
# Epoch 350/400 - Elapsed Time 1793.764168 - Remaining Time 256.252024
# Epoch 351/400 - Elapsed Time 1798.713241 - Remaining Time 251.102418
# Epoch 352/400 - Elapsed Time 1803.662045 - Remaining Time 245.953915
# Epoch 353/400 - Elapsed Time 1808.662004 - Remaining Time 240.813355
# Epoch 354/400 - Elapsed Time 1813.698491 - Remaining Time 235.678335
# Epoch 355/400 - Elapsed Time 1818.792456 - Remaining Time 230.551156
# Epoch 356/400 - Elapsed Time 1824.137269 - Remaining Time 225.455168
# Epoch 357/400 - Elapsed Time 1829.304287 - Remaining Time 220.336371
# Epoch 358/400 - Elapsed Time 1834.180275 - Remaining Time 215.183161
# Epoch 359/400 - Elapsed Time 1839.467312 - Remaining Time 210.078440
# Epoch 360/400 - Elapsed Time 1844.421192 - Remaining Time 204.935688
# Epoch 361/400 - Elapsed Time 1849.324488 - Remaining Time 199.788518
# Epoch 362/400 - Elapsed Time 1854.291121 - Remaining Time 194.649344
# Epoch 363/400 - Elapsed Time 1859.324131 - Remaining Time 189.517887
# Epoch 364/400 - Elapsed Time 1864.318623 - Remaining Time 184.383160
# Epoch 365/400 - Elapsed Time 1869.412906 - Remaining Time 179.258772
# Epoch 366/400 - Elapsed Time 1874.313669 - Remaining Time 174.116570
# Epoch 367/400 - Elapsed Time 1879.224555 - Remaining Time 168.976595
# Epoch 368/400 - Elapsed Time 1884.104552 - Remaining Time 163.835178
# Epoch 369/400 - Elapsed Time 1889.165615 - Remaining Time 158.710390
# Epoch 370/400 - Elapsed Time 1896.062532 - Remaining Time 153.734800
# Epoch 371/400 - Elapsed Time 1901.441051 - Remaining Time 148.630163
# Epoch 372/400 - Elapsed Time 1906.781697 - Remaining Time 143.521203
# Epoch 373/400 - Elapsed Time 1911.751891 - Remaining Time 138.384185
# Epoch 374/400 - Elapsed Time 1916.725510 - Remaining Time 133.248297
# Epoch 375/400 - Elapsed Time 1921.688909 - Remaining Time 128.112594
# Epoch 376/400 - Elapsed Time 1926.703262 - Remaining Time 122.981059
# Epoch 377/400 - Elapsed Time 1931.613730 - Remaining Time 117.843808
# Epoch 378/400 - Elapsed Time 1936.648084 - Remaining Time 112.714968
# Epoch 379/400 - Elapsed Time 1941.619818 - Remaining Time 107.583156
# Epoch 380/400 - Elapsed Time 1946.726512 - Remaining Time 102.459290
# Epoch 381/400 - Elapsed Time 1951.659831 - Remaining Time 97.326868
# Epoch 382/400 - Elapsed Time 1956.525782 - Remaining Time 92.192314
# Epoch 383/400 - Elapsed Time 1961.403618 - Remaining Time 87.059691
# Epoch 384/400 - Elapsed Time 1966.328834 - Remaining Time 81.930368
# Epoch 385/400 - Elapsed Time 1971.276950 - Remaining Time 76.802998
# Epoch 386/400 - Elapsed Time 1976.259878 - Remaining Time 71.677819
# Epoch 387/400 - Elapsed Time 1981.722836 - Remaining Time 66.569501
# Epoch 388/400 - Elapsed Time 1987.058411 - Remaining Time 61.455415
# Epoch 389/400 - Elapsed Time 1991.985477 - Remaining Time 56.328638
# Epoch 390/400 - Elapsed Time 1996.979808 - Remaining Time 51.204610
# Epoch 391/400 - Elapsed Time 2002.192751 - Remaining Time 46.086278
# Epoch 392/400 - Elapsed Time 2007.121555 - Remaining Time 40.961664
# Epoch 393/400 - Elapsed Time 2012.090847 - Remaining Time 35.838768
# Epoch 394/400 - Elapsed Time 2016.986203 - Remaining Time 30.715526
# Epoch 395/400 - Elapsed Time 2021.945071 - Remaining Time 25.594241
# Epoch 396/400 - Elapsed Time 2026.898118 - Remaining Time 20.473718
# Epoch 397/400 - Elapsed Time 2031.944072 - Remaining Time 15.354741
# Epoch 398/400 - Elapsed Time 2036.842490 - Remaining Time 10.235389
# Epoch 399/400 - Elapsed Time 2041.824041 - Remaining Time 5.117353
# Epoch 400/400 - Elapsed Time 2046.907952 - Remaining Time 0.000000

# %% [markdown]
# The next block will run prediction on the test set and save the output detections

# %%
from __future__ import division
from __future__ import print_function

import numpy as np
import torch
from torch.utils.data import DataLoader
from torchvision import transforms

from hourglass import hg

from dataset import Dataset
from dataset import CropAndPad, LocsToHeatmaps, ToTensor, Normalize
from tqdm import tqdm

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = hg(num_stacks=1, num_blocks=1, num_classes=10).to(device)
checkpoint = torch.load('/content/gdrive/My Drive/cis580-2019-hw6/model_checkpoint.pt')
model.load_state_dict(checkpoint['model'])
transform_list = [CropAndPad(out_size=(256, 256))]
transform_list.append(LocsToHeatmaps(out_size=(64,64)))
transform_list.append(ToTensor())
transform_list.append(Normalize())
test_ds = Dataset(is_train=False, transform=transforms.Compose(transform_list))
data_loader = DataLoader(test_ds, batch_size=1, pin_memory=True, shuffle=False)
predicted_heatmaps = np.zeros((len(test_ds), 10, 64, 64))
for i, batch in enumerate(tqdm(data_loader)):
    model.eval()
    images = batch['image'].to(device)
    with torch.no_grad():
        pred_heatmap_list = model(images)
    pred_heatmaps = pred_heatmap_list[-1]
    predicted_heatmaps[i,:,:,:] = pred_heatmaps[0,:,:,:].cpu().numpy()
np.save('/content/gdrive/My Drive/cis580-2019-hw6/detections.npy', predicted_heatmaps)
# Out:
# 100%|██████████| 27/27 [00:00<00:00, 31.27it/s]

# %% [markdown]
# Import the external and given functions for step 2

# %%
import numpy as np
import torch
import torch.nn as nn
import cv2
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import os
from os.path import join
from utils import plot_mesh

"""
Convert axis-angle representation to a 3x3 rotation matrix
"""
class Rodrigues(torch.autograd.Function):
    @staticmethod
    def forward(self, inp):
        pose = inp.detach().cpu().numpy()
        rotm, part_jacob = cv2.Rodrigues(pose)
        self.jacob = torch.Tensor(np.transpose(part_jacob)).contiguous()
        rotation_matrix = torch.Tensor(rotm.ravel())
        return rotation_matrix.view(3,3)

    @staticmethod
    def backward(self, grad_output):
        grad_output = grad_output.view(1,-1)
        grad_input = torch.mm(grad_output, self.jacob)
        grad_input = grad_input.view(-1)
        return grad_input
"""
This is the function you should call to convert fom axis-angle to a rotation matrix
Example usage:
    aa = torch.zeros(3)
    R = rodrigues(aa)
"""
rodrigues = Rodrigues.apply

# %% [markdown]
# Step 2) Implement pose_optimization and heatmaps_to_locs as specified by the accompanying PDF

# %%
"""
YOU NEED TO IMPLEMENT THIS
Input: image, mesh vertices, mesh faces, detected 2d keypoints, keypoint confidences, 3D keypoint coordinates in the canonical position, intrinsic camera matrix
Output: R, t
"""
def pose_optimization(img, vertices, faces, keypoints_2d, conf, keypoints_3d, K):
    # Send variables to GPU
    device = keypoints_2d.device
    keypoints_3d = keypoints_3d.to(device)
    K = K.to(device)
    r = torch.rand(3, requires_grad=True, device=device) # rotation in axis-angle representation
    t = torch.rand(3 ,requires_grad=True, device=device)
    d = conf.sqrt()[:, None]
    # 2D keypoints in normalized coordinates
    norm_keypoints_2d = torch.matmul(K.inverse(), torch.cat((keypoints_2d, torch.ones(keypoints_2d.shape[0],1, device=device)), dim=-1).t()).t()[:,:-1]
    # set up optimizer
    optimizer = torch.optim.Adam([r,t], lr=1e-2)
    # converge check
    converged = False
    rel_tol = 1e-5
    loss_old = 100
    while not converged:
      # convert axis-angle to rotation matrix
      R = rodrigues(r)
      # 1) Compute projected keypoints based on current estimate of R and t
      optimizer.zero_grad()
      k3d = torch.matmul(R, keypoints_3d.transpose(1,0)) + t[:, None]
      proj_keypoints = (k3d / k3d[2]).transpose(1,0)
      proj_keypoints = proj_keypoints[:,:2]
      # 2) Compute error (based on distance between projected keypoints and detected keypoints)
      err = torch.sum(((norm_keypoints_2d - proj_keypoints) * d) ** 2)                        
      # 3) Update based on error
      err.backward()
      optimizer.step()                   
      # 4) Check for convergence
      if abs(err.detach() - loss_old) / loss_old < rel_tol:
        converged = True
      else:
        loss_old = err.detach()                    
      # IMPLEMENT THE ABOVE
    
      
      
           
        
                      

    R = rodrigues(r)
    plt.figure()
    plot_mesh(img, vertices, faces, R.detach().cpu().numpy(), t.detach().cpu().numpy()[:,None], K.detach().cpu().numpy())
    pk = torch.matmul(K, torch.cat((proj_keypoints, torch.ones(proj_keypoints.shape[0], 1, device=device)), dim=-1).t()).t()
    pk = pk.detach().cpu().numpy()
    plt.scatter(pk[:,0], pk[:,1], color='r')
    plt.show()
    return rodrigues(r)[0].detach(), t.detach()

"""
YOU NEED TO IMPLEMENT THIS
Convert heatmaps to 2D locations
Input: Nx10x64x64 keypoint heatmaps
Output: Nx10x3 keypoint locations and detection confidence (magnitude of the highest activation)
"""
def heatmaps_to_locs(heatmaps):
    heatmaps = heatmaps.numpy()
    conf = np.max(heatmaps, axis = (-2,-1)) 
    per_heatmap = heatmaps.reshape((*heatmaps.shape[:2], -1))  
    locs = np.argmax(per_heatmap, axis = -1)        
    arr = np.unravel_index(locs, (64, 64)) 
    temp = np.copy(arr[0]) 
    arr[0][:] = arr[1][:]
    arr[1][:] = np.copy(temp)
    
    locs = np.stack(arr, axis = -1)    
    return torch.from_numpy(np.concatenate([locs, conf[..., None]], axis = -1).astype('float32'))

# %% [markdown]
# The next block will start the pose optimization process. Be sure to run the above block first every time you want to test changes to the code.

# %%
data = np.load('data/misc_data.npz')
K = torch.from_numpy(data['K']).float()
S = torch.from_numpy(np.load('data/kpt.npy'))
vertices = data['vertices']
faces = data['faces']

dataset = np.load('data/valid_data.npz')
imgnames = dataset['imgname']
scales = torch.from_numpy(dataset['scale']).float()[:,None]
centers = torch.from_numpy(dataset['center']).float()
# detections.npy contains the detections saved after training your model and running predict.py
heatmaps = torch.from_numpy(np.load('/content/gdrive/My Drive/cis580-2019-hw6/detections.npy'))

keypoint_locs = heatmaps_to_locs(heatmaps)

# Compute detected 2D keypoint locations in the original image
ul_corner = centers - scales * 100
keypoint_locs[:,:,:-1] *= scales[:,:,None]*200 / 64
keypoint_locs[:,:,:-1] += ul_corner[:,None,:]

images = np.load('data/images.npz')

os.makedirs('/content/gdrive/My Drive/cis580-2019-hw6/pose_optimization', exist_ok=True)
for i in range(len(heatmaps)):
    img_name = imgnames[i].decode('utf-8')
    print("Processing ", img_name)
    img = images[img_name]
    pose_optimization(img, vertices, faces, keypoint_locs[i,:,:-1], keypoint_locs[i,:,-1], S, K)
    plt.savefig('/content/gdrive/My Drive/cis580-2019-hw6/pose_optimization/%s' % img_name, dpi=300)
    plt.close('all')
# Out:
# Processing  train_148.jpg
# Processing  train_160.jpg
# Processing  train_80.jpg
# Processing  train_181.jpg
# Processing  train_176.jpg
# Processing  train_2.jpg
# Processing  train_155.jpg
# Processing  train_136.jpg
# Processing  train_4.jpg
# Processing  train_18.jpg
# Processing  train_106.jpg
# Processing  train_90.jpg
# Processing  train_25.jpg
# Processing  train_116.jpg
# Processing  train_190.jpg
# Processing  train_177.jpg
# Processing  train_52.jpg
# Processing  train_191.jpg
# Processing  train_13.jpg
# Processing  train_9.jpg
# Processing  train_81.jpg
# Processing  train_21.jpg
# Processing  train_72.jpg
# Processing  train_144.jpg
# Processing  train_10.jpg
# Processing  train_12.jpg
# Processing  train_140.jpg
